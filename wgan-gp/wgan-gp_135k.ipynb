# %%
import os
import random
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML
import kagglehub 
import json

# %%
# Batch size during training
batch_size = 128

# Spatial size of training images. All images will be resized to this
#   size using a transformer.
img_size = 64

# Number of channels in the training images. For color images this is 3
img_channels = 3

# Size of z latent vector (i.e. size of generator input)
latent_size = 100

# Number of training epochs
num_epochs = 100

# Learning rate for optimizers
lr = 0.0001

# Beta hyperparameters for Adam optimizers
betas = (0.0, 0.9)

# %%
# dataset_name = "soumikrakshit/anime-faces"
# dataset_name = "splcher/animefacedataset"
dataset_name = "ziggykor/anime-face-dataset-expanded-2024"

formatted_dataset_name = dataset_name.replace("/","_")
path = kagglehub.dataset_download(dataset_name)

print("Path to dataset files:" , path)
# Out:
# Path to dataset files: /Users/yusuf/.cache/kagglehub/datasets/ziggykor/anime-face-dataset-expanded-2024/versions/1

# %%
dataset = dset.ImageFolder(root=path,
                           transform=transforms.Compose([
                               transforms.Resize(img_size),
                               transforms.CenterCrop(img_size),
                               transforms.ToTensor(),
                               transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                           ]))

dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size,
                                         shuffle=True)

print(f"Number of images in the dataset is {len(dataset)}")
# Out:
# Number of images in the dataset is 135027

# %%
dataset_without_transforms = dset.ImageFolder(root=path)

# %%
dataset[0][0].shape # each image has 3 channels and has a resolution of 64x64
# Out:
# torch.Size([3, 64, 64])

# %%
print(f"min value in dataset[0][0]: {dataset[0][0].min()}")
print(f"max value in dataset[0][0]: {dataset[0][0].max()}")
# Out:
# min value in dataset[0][0]: -0.8039215803146362
# max value in dataset[0][0]: 1.0

# %%
image_idx = np.random.randint(low=0, high=len(dataset), size=(4))
image_idx
# Out:
# array([ 75209, 100751, 107087,  18436])

# %%
fix, ax = plt.subplots(ncols=4, nrows=1, figsize=(12,3))
plt.suptitle("Sample Anime Faces before transformation") 

for i in range(4):
    idx = image_idx[i]
    ax[i].imshow(dataset_without_transforms[idx][0])

# %%
def denorm(img_tensors):
    return img_tensors * .5 + .5
    
fix, ax = plt.subplots(ncols=4, nrows=1, figsize=(12,3))
plt.suptitle("Sample Anime Faces after transformation")  # Adjust y-value

for i in range(4):
    idx = image_idx[i]
    ax[i].imshow(denorm(dataset[idx][0]).permute(1,2,0).detach().numpy())
plt.show()

# %%
# ## Select Device for Training
def get_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    elif torch.backends.mps.is_available():
        return torch.device("mps")
    else:
        return torch.device("cpu")

# Decide which device we want to run on
device = get_device()
print("Using device:", device)
# Out:
# Using device: mps

# %%
real_batch = next(iter(dataloader))
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0].to(device)[:64], padding=2, normalize=True).cpu(),(1,2,0)))
plt.show()

# %%
# custom weights initialization
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1 or classname.find('InstanceNorm') != -1:
        if hasattr(m, 'weight') and m.weight is not None:
            nn.init.normal_(m.weight.data, 1.0, 0.02)
        if hasattr(m, 'bias') and m.bias is not None:
            nn.init.constant_(m.bias.data, 0)

# %%
# Generator Code

class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.main = nn.Sequential(
            # input is latent_size x 1 x 1
            nn.ConvTranspose2d(latent_size, 64 * 8, 4, 1, 0, bias=False),
            nn.BatchNorm2d(64 * 8),
            nn.ReLU(True),
            # out: (64*8) x 4 x 4
            nn.ConvTranspose2d(64 * 8, 64 * 4, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64 * 4),
            nn.ReLU(True),
            # state size. ``(64*4) x 8 x 8``
            nn.ConvTranspose2d( 64 * 4, 64 * 2, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64 * 2),
            nn.ReLU(True),
            # state size. ``(64*2) x 16 x 16``
            nn.ConvTranspose2d( 64 * 2, 64, 4, 2, 1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(True),
            # state size. (64) x 32 x 32
            nn.ConvTranspose2d( 64, img_channels, 4, 2, 1, bias=False),
            nn.Tanh()
            # state size. (3) x 64 x 64
        )

    def forward(self, input):
        return self.main(input)

# %%
generator = Generator().to(device)

generator.apply(weights_init)

print(generator)
# Out:
# Generator(
#   (main): Sequential(
#     (0): ConvTranspose2d(100, 512, kernel_size=(4, 4), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU(inplace=True)
#     (9): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (10): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): ReLU(inplace=True)
#     (12): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (13): Tanh()
#   )
# )

# %%
class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()
        self.main = nn.Sequential(
            # input is 3 x 64 x 64
            nn.Conv2d(img_channels, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            # out: 64 x 32 x 32
            nn.Conv2d(64, 64 * 2, 4, 2, 1, bias=False),
            nn.InstanceNorm2d(64 * 2),  # use InstanceNorm2d instead of BatchNorm2d
            nn.LeakyReLU(0.2, inplace=True),
            # out: (64*2) x 16 x 16
            nn.Conv2d(64 * 2, 64 * 4, 4, 2, 1, bias=False),
            nn.InstanceNorm2d(64 * 4),
            nn.LeakyReLU(0.2, inplace=True),
            # out: (64*4) x 8 x 8
            nn.Conv2d(64 * 4, 64 * 8, 4, 2, 1, bias=False),
            nn.InstanceNorm2d(64 * 8),
            nn.LeakyReLU(0.2, inplace=True),
            # out: (64*8) x 4 x 4
            nn.Conv2d(64 * 8, 1, 4, 1, 0, bias=False),
            # out: 1 x 1 x 1

            # Note: No sigmoid in wgan-gp
            # nn.Sigmoid()
        )

    def forward(self, input):
        return self.main(input)

# %%
# Create the Discriminator
critic = Critic().to(device)

critic.apply(weights_init)

print(critic)
# Out:
# Critic(
#   (main): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (3): InstanceNorm2d(128, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (4): LeakyReLU(negative_slope=0.2, inplace=True)
#     (5): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (6): InstanceNorm2d(256, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (7): LeakyReLU(negative_slope=0.2, inplace=True)
#     (8): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (9): InstanceNorm2d(512, eps=1e-05, momentum=0.1, affine=False, track_running_stats=False)
#     (10): LeakyReLU(negative_slope=0.2, inplace=True)
#     (11): Conv2d(512, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   )
# )

# %%
def compute_gradient_penalty(critic, real_samples, fake_samples, device, lambda_gp=10):
    batch_size = real_samples.size(0)
    epsilon = torch.rand(batch_size, 1, 1, 1, device=device)
    interpolated = epsilon * real_samples + (1 - epsilon) * fake_samples
    interpolated.requires_grad_(True)
    
    # Get critic scores for interpolated samples
    interpolated_scores = critic(interpolated).view(-1)
    
    # Compute gradients of scores with respect to interpolated images
    gradients = torch.autograd.grad(
        outputs=interpolated_scores,
        inputs=interpolated,
        grad_outputs=torch.ones_like(interpolated_scores, device=device),
        create_graph=True,
        retain_graph=True,
        only_inputs=True
    )[0]
    
    gradients = gradients.view(batch_size, -1)
    gradient_norm = gradients.norm(2, dim=1)
    penalty = lambda_gp * ((gradient_norm - 1) ** 2).mean()
    return penalty

# %%
# criterion = nn.BCELoss()

# fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# real_label = 1.
# fake_label = 0.

optimizerC = optim.Adam(critic.parameters(), lr=lr, betas=betas)
optimizerG = optim.Adam(generator.parameters(), lr=lr, betas=betas)

# %%
sample_dir = f"generated_images/{formatted_dataset_name}"
os.makedirs(sample_dir, exist_ok=True)

# %%
import torch
import torchvision.utils as vutils
import matplotlib.pyplot as plt
import os

def save_samples(index, latent_tensors, generator, show=True):
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    
    with torch.no_grad():
        fake = generator(latent_tensors).detach().cpu()
    
    # Convert tensor to image grid
    grid = vutils.make_grid(fake, padding=2, normalize=True).permute(1, 2, 0).numpy()
    
    # Plot and add a title
    plt.figure(figsize=(8, 8))
    plt.imshow(grid)
    plt.axis("off")  # Remove axis for a cleaner image
    plt.title(f"WGAN-GP, Epoch: {index}, Dataset: {dataset_name}")
    
    # Show the image if requested
    if show:
        plt.show()
    
    # Save the image with the title
    plt.savefig(os.path.join(sample_dir, fake_fname), bbox_inches="tight", pad_inches=0.2)
    plt.close()

# %%
latent_size=100
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
models_dir = f"models/{formatted_dataset_name}"
os.makedirs(models_dir, exist_ok=True)

# %%
def train_wgan_gp(num_epochs, dataloader, generator, critic, optimizerG, optimizerC, device, latent_size, fixed_latent, n_critic=5):
    G_losses = []
    C_losses = []
    
    print("Starting WGAN-GP Training Loop...")
    save_samples(0, fixed_latent, generator, show=False)

    for epoch in range(num_epochs):
        for i, data in enumerate(dataloader, 0):
            real_images = data[0].to(device)
            batch_size = real_images.size(0)
            
            # ---------------------
            #  Train Critic
            # ---------------------
            critic.zero_grad()
            
            # Generate fake images
            noise = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = generator(noise).detach()
            
            # Critic outputs
            critic_real = critic(real_images).view(-1)
            critic_fake = critic(fake_images).view(-1)
            
            # Compute gradient penalty
            gp = compute_gradient_penalty(critic, real_images, fake_images, device)
            
            # Critic loss: maximize D(real) - D(fake) => minimize loss = D(fake) - D(real) + gp
            loss_critic = critic_fake.mean() - critic_real.mean() + gp
            loss_critic.backward()
            optimizerC.step()
            
            C_losses.append(loss_critic.item())
            
            # Update generator every n_critic iterations
            if i % n_critic == 0:
                generator.zero_grad()
                noise = torch.randn(batch_size, latent_size, 1, 1, device=device)
                fake_images = generator(noise)
                # Generator loss: minimize -D(fake) (i.e., maximize D(fake))
                loss_generator = -critic(fake_images).view(-1).mean()
                loss_generator.backward()
                optimizerG.step()
                G_losses.append(loss_generator.item())
            else:
                # Append None when generator is not updated
                G_losses.append(None)
            
            # (Optional) Print metrics every so often
            if i % 100 == 0:
                print(f'Epoch [{epoch}/{num_epochs}] Batch [{i}/{len(dataloader)}] '
                      f'Loss_Critic: {loss_critic.item():.4f}  Loss_Generator: {loss_generator.item():.4f}')
        
        save_samples(epoch+1, fixed_latent, generator, show=False)
        
        # Save model every 10 epochs
        if (epoch + 1) % 10 == 0:
            torch.save({
                'generator_state_dict': generator.state_dict(),
                'epoch': epoch + 1,
            }, f'{models_dir}/generator_checkpoint_epoch_{epoch+1}.pth')
            print(f'Model checkpoint saved at epoch {epoch+1}')
    
    return G_losses, C_losses

# %%
G_losses, C_losses = train_wgan_gp(
    num_epochs=num_epochs,
    dataloader=dataloader,
    generator=generator,
    critic=critic,
    optimizerG=optimizerG,
    optimizerC=optimizerC,
    device=device,
    latent_size=latent_size,
    fixed_latent=fixed_latent,
)
# Out:
# Starting WGAN-GP Training Loop...
# Epoch [0/100] Batch [0/1055] Loss_Critic: 718.5667  Loss_Generator: 1.2220
# Epoch [0/100] Batch [100/1055] Loss_Critic: -11.5714  Loss_Generator: 6.1888
# Epoch [0/100] Batch [200/1055] Loss_Critic: -17.3735  Loss_Generator: 1.9499
# Epoch [0/100] Batch [300/1055] Loss_Critic: -17.5086  Loss_Generator: 1.2912
# Epoch [0/100] Batch [400/1055] Loss_Critic: -17.3382  Loss_Generator: 6.9774
# Epoch [0/100] Batch [500/1055] Loss_Critic: -17.5490  Loss_Generator: 6.2997
# Epoch [0/100] Batch [600/1055] Loss_Critic: -17.6045  Loss_Generator: 13.9991
# Epoch [0/100] Batch [700/1055] Loss_Critic: -14.5535  Loss_Generator: 9.9094
# Epoch [0/100] Batch [800/1055] Loss_Critic: -14.8136  Loss_Generator: 14.6954
# Epoch [3/100] Batch [900/1055] Loss_Critic: -11.4469  Loss_Generator: 24.4374
# Epoch [3/100] Batch [1000/1055] Loss_Critic: -11.6406  Loss_Generator: 26.0254
# Epoch [4/100] Batch [0/1055] Loss_Critic: -11.6968  Loss_Generator: 22.6247
# Epoch [4/100] Batch [100/1055] Loss_Critic: -11.7439  Loss_Generator: 24.5210
# Epoch [4/100] Batch [200/1055] Loss_Critic: -11.4304  Loss_Generator: 23.7736
# Epoch [4/100] Batch [300/1055] Loss_Critic: -11.4849  Loss_Generator: 24.9323
# Epoch [4/100] Batch [400/1055] Loss_Critic: -11.6892  Loss_Generator: 23.5439
# Epoch [4/100] Batch [500/1055] Loss_Critic: -12.3640  Loss_Generator: 23.5595
# Epoch [4/100] Batch [600/1055] Loss_Critic: -12.1726  Loss_Generator: 25.5216
# Epoch [4/100] Batch [700/1055] Loss_Critic: -10.6709  Loss_Generator: 24.8681
# Epoch [4/100] Batch [800/1055] Loss_Critic: -11.3087  Loss_Generator: 23.7146
# Epoch [4/100] Batch [900/1055] Loss_Critic: -11.4012  Loss_Generator: 23.9681
# Epoch [4/100] Batch [1000/1055] Loss_Critic: -10.2674  Loss_Generator: 23.1042
# Epoch [5/100] Batch [0/1055] Loss_Critic: -10.8999  Loss_Generator: 22.6850
# Epoch [5/100] Batch [100/1055] Loss_Critic: -11.1004  Loss_Generator: 25.2025
# Epoch [5/100] Batch [200/1055] Loss_Critic: -10.9422  Loss_Generator: 25.6064
# Epoch [5/100] Batch [300/1055] Loss_Critic: -11.3475  Loss_Generator: 25.1703
# Epoch [5/100] Batch [400/1055] Loss_Critic: -12.0307  Loss_Generator: 24.4071
# Epoch [5/100] Batch [500/1055] Loss_Critic: -11.4585  Loss_Generator: 22.9544
# Epoch [5/100] Batch [600/1055] Loss_Critic: -10.5154  Loss_Generator: 25.1271
# Epoch [5/100] Batch [700/1055] Loss_Critic: -11.1354  Loss_Generator: 25.8096
# Epoch [5/100] Batch [800/1055] Loss_Critic: -10.3233  Loss_Generator: 23.7754
# Epoch [5/100] Batch [900/1055] Loss_Critic: -11.5324  Loss_Generator: 24.3920
# Epoch [5/100] Batch [1000/1055] Loss_Critic: -10.4516  Loss_Generator: 25.2664
# Epoch [6/100] Batch [0/1055] Loss_Critic: -11.2949  Loss_Generator: 23.6770
# Epoch [6/100] Batch [100/1055] Loss_Critic: -10.7850  Loss_Generator: 25.4949
# Epoch [6/100] Batch [200/1055] Loss_Critic: -10.0423  Loss_Generator: 23.0070
# Epoch [6/100] Batch [300/1055] Loss_Critic: -11.4490  Loss_Generator: 25.0924
# Epoch [6/100] Batch [400/1055] Loss_Critic: -11.2706  Loss_Generator: 24.4378
# Epoch [6/100] Batch [500/1055] Loss_Critic: -10.9653  Loss_Generator: 26.9453
# Epoch [6/100] Batch [600/1055] Loss_Critic: -10.0230  Loss_Generator: 25.5915
# Epoch [6/100] Batch [700/1055] Loss_Critic: -10.1229  Loss_Generator: 25.7983
# Epoch [6/100] Batch [800/1055] Loss_Critic: -9.4304  Loss_Generator: 24.9797
# Epoch [6/100] Batch [900/1055] Loss_Critic: -9.5122  Loss_Generator: 24.0676
# Epoch [6/100] Batch [1000/1055] Loss_Critic: -9.3375  Loss_Generator: 24.3675
# Epoch [7/100] Batch [0/1055] Loss_Critic: -9.8669  Loss_Generator: 24.9122
# Epoch [7/100] Batch [100/1055] Loss_Critic: -10.4347  Loss_Generator: 25.0738
# Epoch [7/100] Batch [200/1055] Loss_Critic: -9.4911  Loss_Generator: 24.2196
# Epoch [7/100] Batch [300/1055] Loss_Critic: -10.1291  Loss_Generator: 24.7263
# Epoch [7/100] Batch [400/1055] Loss_Critic: -7.8138  Loss_Generator: 27.0763
# Epoch [7/100] Batch [500/1055] Loss_Critic: -9.3290  Loss_Generator: 28.4107
# Epoch [7/100] Batch [600/1055] Loss_Critic: -8.5240  Loss_Generator: 26.9345
# Epoch [7/100] Batch [700/1055] Loss_Critic: -8.8017  Loss_Generator: 25.5735
# Epoch [7/100] Batch [800/1055] Loss_Critic: -9.1647  Loss_Generator: 26.0254
# Epoch [7/100] Batch [900/1055] Loss_Critic: -9.7283  Loss_Generator: 24.7143
# Epoch [7/100] Batch [1000/1055] Loss_Critic: -9.5576  Loss_Generator: 24.5589
# Epoch [8/100] Batch [0/1055] Loss_Critic: -9.8291  Loss_Generator: 23.8054
# Epoch [8/100] Batch [100/1055] Loss_Critic: -9.0783  Loss_Generator: 26.4092
# Epoch [8/100] Batch [200/1055] Loss_Critic: -8.8480  Loss_Generator: 24.7692
# Epoch [8/100] Batch [300/1055] Loss_Critic: -9.1543  Loss_Generator: 26.3232
# Epoch [8/100] Batch [400/1055] Loss_Critic: -8.6998  Loss_Generator: 25.5976
# Epoch [8/100] Batch [500/1055] Loss_Critic: -8.7172  Loss_Generator: 25.7645
# Epoch [8/100] Batch [600/1055] Loss_Critic: -8.9269  Loss_Generator: 24.7100
# Epoch [8/100] Batch [700/1055] Loss_Critic: -9.6993  Loss_Generator: 26.8049
# Epoch [8/100] Batch [800/1055] Loss_Critic: -8.6710  Loss_Generator: 25.1045
# Epoch [8/100] Batch [900/1055] Loss_Critic: -9.4133  Loss_Generator: 27.0095
# Epoch [8/100] Batch [1000/1055] Loss_Critic: -9.1931  Loss_Generator: 28.3304
# Epoch [9/100] Batch [0/1055] Loss_Critic: -8.1258  Loss_Generator: 23.7959
# Epoch [9/100] Batch [100/1055] Loss_Critic: -9.2598  Loss_Generator: 25.9399
# Epoch [9/100] Batch [200/1055] Loss_Critic: -9.0901  Loss_Generator: 25.6341
# Epoch [9/100] Batch [300/1055] Loss_Critic: -8.3682  Loss_Generator: 26.4251
# Epoch [9/100] Batch [400/1055] Loss_Critic: -8.2092  Loss_Generator: 24.8514
# Epoch [9/100] Batch [500/1055] Loss_Critic: -9.1786  Loss_Generator: 25.5020
# Epoch [9/100] Batch [600/1055] Loss_Critic: -7.8693  Loss_Generator: 25.5006
# Epoch [9/100] Batch [700/1055] Loss_Critic: -8.4678  Loss_Generator: 26.2938
# Epoch [9/100] Batch [800/1055] Loss_Critic: -8.7081  Loss_Generator: 23.5964
# Epoch [9/100] Batch [900/1055] Loss_Critic: -8.8570  Loss_Generator: 24.9460
# Epoch [9/100] Batch [1000/1055] Loss_Critic: -8.0261  Loss_Generator: 26.2391
# Model checkpoint saved at epoch 10
# Epoch [10/100] Batch [0/1055] Loss_Critic: -8.6200  Loss_Generator: 25.3042
# Epoch [10/100] Batch [100/1055] Loss_Critic: -7.9259  Loss_Generator: 26.4090
# Epoch [10/100] Batch [200/1055] Loss_Critic: -8.5602  Loss_Generator: 26.5239
# Epoch [10/100] Batch [300/1055] Loss_Critic: -8.2942  Loss_Generator: 26.0423
# Epoch [10/100] Batch [400/1055] Loss_Critic: -7.8123  Loss_Generator: 29.2309
# Epoch [10/100] Batch [500/1055] Loss_Critic: -7.9859  Loss_Generator: 26.5838
# Epoch [10/100] Batch [600/1055] Loss_Critic: -8.6342  Loss_Generator: 25.6330
# Epoch [10/100] Batch [700/1055] Loss_Critic: -8.5782  Loss_Generator: 27.9586
# Epoch [10/100] Batch [800/1055] Loss_Critic: -8.1638  Loss_Generator: 25.9646
# Epoch [10/100] Batch [900/1055] Loss_Critic: -8.3238  Loss_Generator: 28.7944
# Epoch [10/100] Batch [1000/1055] Loss_Critic: -8.0602  Loss_Generator: 26.3675
# Epoch [11/100] Batch [0/1055] Loss_Critic: -8.6743  Loss_Generator: 27.4004
# Epoch [11/100] Batch [100/1055] Loss_Critic: -8.3939  Loss_Generator: 26.4685
# Epoch [11/100] Batch [200/1055] Loss_Critic: -8.7224  Loss_Generator: 27.7735
# Epoch [11/100] Batch [300/1055] Loss_Critic: -8.3608  Loss_Generator: 26.7906
# Epoch [11/100] Batch [400/1055] Loss_Critic: -8.2589  Loss_Generator: 24.2669
# Epoch [11/100] Batch [500/1055] Loss_Critic: -7.0750  Loss_Generator: 26.1961
# Epoch [11/100] Batch [600/1055] Loss_Critic: -8.6745  Loss_Generator: 28.7060
# Epoch [11/100] Batch [700/1055] Loss_Critic: -7.4426  Loss_Generator: 28.3234
# Epoch [11/100] Batch [800/1055] Loss_Critic: -8.0335  Loss_Generator: 26.2997
# Epoch [11/100] Batch [900/1055] Loss_Critic: -7.5421  Loss_Generator: 26.3538
# Epoch [11/100] Batch [1000/1055] Loss_Critic: -8.3253  Loss_Generator: 27.3839
# Epoch [12/100] Batch [0/1055] Loss_Critic: -7.6069  Loss_Generator: 27.1873
# Epoch [12/100] Batch [100/1055] Loss_Critic: -8.1236  Loss_Generator: 26.0531
# Epoch [12/100] Batch [200/1055] Loss_Critic: -8.4141  Loss_Generator: 26.4043
# Epoch [12/100] Batch [300/1055] Loss_Critic: -8.1927  Loss_Generator: 27.5873
# Epoch [12/100] Batch [400/1055] Loss_Critic: -7.7173  Loss_Generator: 27.0937
# Epoch [12/100] Batch [500/1055] Loss_Critic: -8.9962  Loss_Generator: 26.7030
# Epoch [12/100] Batch [600/1055] Loss_Critic: -8.0901  Loss_Generator: 28.0308
# Epoch [12/100] Batch [700/1055] Loss_Critic: -7.3887  Loss_Generator: 25.2810
# Epoch [12/100] Batch [800/1055] Loss_Critic: -8.3659  Loss_Generator: 27.3780
# Epoch [12/100] Batch [900/1055] Loss_Critic: -8.7812  Loss_Generator: 24.9641
# Epoch [12/100] Batch [1000/1055] Loss_Critic: -7.8028  Loss_Generator: 28.5948
# Epoch [13/100] Batch [0/1055] Loss_Critic: -8.5291  Loss_Generator: 26.9534
# Epoch [13/100] Batch [100/1055] Loss_Critic: -7.7735  Loss_Generator: 25.2892
# Epoch [13/100] Batch [200/1055] Loss_Critic: -9.7309  Loss_Generator: 26.1687
# Epoch [13/100] Batch [300/1055] Loss_Critic: -7.8816  Loss_Generator: 25.8107
# Epoch [13/100] Batch [400/1055] Loss_Critic: -7.8470  Loss_Generator: 28.2677
# Epoch [13/100] Batch [500/1055] Loss_Critic: -8.1898  Loss_Generator: 29.5191
# Epoch [13/100] Batch [600/1055] Loss_Critic: -8.1496  Loss_Generator: 28.6105
# Epoch [13/100] Batch [700/1055] Loss_Critic: -8.0111  Loss_Generator: 25.1462
# Epoch [13/100] Batch [800/1055] Loss_Critic: -7.8869  Loss_Generator: 26.5888
# Epoch [13/100] Batch [900/1055] Loss_Critic: -6.5176  Loss_Generator: 27.5619
# Epoch [13/100] Batch [1000/1055] Loss_Critic: -7.1741  Loss_Generator: 23.6986
# Epoch [14/100] Batch [0/1055] Loss_Critic: -8.6373  Loss_Generator: 27.6548
# Epoch [14/100] Batch [100/1055] Loss_Critic: -7.8363  Loss_Generator: 26.2705
# Epoch [14/100] Batch [200/1055] Loss_Critic: -7.0907  Loss_Generator: 26.2500
# Epoch [14/100] Batch [300/1055] Loss_Critic: -8.1889  Loss_Generator: 27.5069
# Epoch [14/100] Batch [400/1055] Loss_Critic: -7.5498  Loss_Generator: 26.1316
# Epoch [14/100] Batch [500/1055] Loss_Critic: -7.3071  Loss_Generator: 27.8741
# Epoch [14/100] Batch [600/1055] Loss_Critic: -7.4422  Loss_Generator: 28.4223
# Epoch [14/100] Batch [700/1055] Loss_Critic: -7.5551  Loss_Generator: 24.6607
# Epoch [14/100] Batch [800/1055] Loss_Critic: -7.7797  Loss_Generator: 25.8540
# Epoch [14/100] Batch [900/1055] Loss_Critic: -7.7022  Loss_Generator: 26.0123
# Epoch [14/100] Batch [1000/1055] Loss_Critic: -8.1574  Loss_Generator: 27.9247
# Epoch [15/100] Batch [0/1055] Loss_Critic: -7.4270  Loss_Generator: 25.2729
# Epoch [15/100] Batch [100/1055] Loss_Critic: -7.6588  Loss_Generator: 26.5524
# Epoch [15/100] Batch [200/1055] Loss_Critic: -7.2650  Loss_Generator: 27.6080
# Epoch [15/100] Batch [300/1055] Loss_Critic: -7.5948  Loss_Generator: 26.6820
# Epoch [15/100] Batch [400/1055] Loss_Critic: -7.6727  Loss_Generator: 25.7374
# Epoch [15/100] Batch [500/1055] Loss_Critic: -7.3770  Loss_Generator: 26.2160
# Epoch [15/100] Batch [600/1055] Loss_Critic: -7.1452  Loss_Generator: 24.0501
# Epoch [15/100] Batch [700/1055] Loss_Critic: -7.6824  Loss_Generator: 26.0239
# Epoch [15/100] Batch [800/1055] Loss_Critic: -7.2754  Loss_Generator: 25.1087
# Epoch [15/100] Batch [900/1055] Loss_Critic: -7.2673  Loss_Generator: 25.1537
# Epoch [15/100] Batch [1000/1055] Loss_Critic: -7.3664  Loss_Generator: 26.5088
# Epoch [16/100] Batch [0/1055] Loss_Critic: -6.5194  Loss_Generator: 26.7927
# Epoch [16/100] Batch [100/1055] Loss_Critic: -7.8679  Loss_Generator: 26.4138
# Epoch [16/100] Batch [200/1055] Loss_Critic: -7.1758  Loss_Generator: 23.7909
# Epoch [16/100] Batch [300/1055] Loss_Critic: -6.7040  Loss_Generator: 26.8143
# Epoch [16/100] Batch [400/1055] Loss_Critic: -7.5060  Loss_Generator: 25.0543
# Epoch [16/100] Batch [500/1055] Loss_Critic: -7.5487  Loss_Generator: 25.4914
# Epoch [16/100] Batch [600/1055] Loss_Critic: -7.0926  Loss_Generator: 25.5073
# Epoch [16/100] Batch [700/1055] Loss_Critic: -7.5424  Loss_Generator: 24.0791
# Epoch [16/100] Batch [800/1055] Loss_Critic: -7.7275  Loss_Generator: 26.3099
# Epoch [16/100] Batch [900/1055] Loss_Critic: -6.9042  Loss_Generator: 27.8884
# Epoch [16/100] Batch [1000/1055] Loss_Critic: -7.9990  Loss_Generator: 26.0061
# Epoch [17/100] Batch [0/1055] Loss_Critic: -7.1589  Loss_Generator: 24.1406
# Epoch [17/100] Batch [100/1055] Loss_Critic: -7.7922  Loss_Generator: 24.8639
# Epoch [17/100] Batch [200/1055] Loss_Critic: -7.2024  Loss_Generator: 28.2796
# Epoch [17/100] Batch [300/1055] Loss_Critic: -7.3757  Loss_Generator: 26.7202
# Epoch [17/100] Batch [400/1055] Loss_Critic: -7.7859  Loss_Generator: 25.6517
# Epoch [17/100] Batch [500/1055] Loss_Critic: -7.0305  Loss_Generator: 27.4153
# Epoch [17/100] Batch [600/1055] Loss_Critic: -7.3235  Loss_Generator: 24.8601
# Epoch [17/100] Batch [700/1055] Loss_Critic: -7.5883  Loss_Generator: 26.0159
# Epoch [17/100] Batch [800/1055] Loss_Critic: -7.9598  Loss_Generator: 25.2578
# Epoch [17/100] Batch [900/1055] Loss_Critic: -7.4871  Loss_Generator: 24.3227
# Epoch [17/100] Batch [1000/1055] Loss_Critic: -6.7996  Loss_Generator: 25.4531
# Epoch [18/100] Batch [0/1055] Loss_Critic: -7.0651  Loss_Generator: 26.3182
# Epoch [18/100] Batch [100/1055] Loss_Critic: -6.4409  Loss_Generator: 26.8107
# Epoch [18/100] Batch [200/1055] Loss_Critic: -7.3756  Loss_Generator: 24.9246
# Epoch [18/100] Batch [300/1055] Loss_Critic: -7.3621  Loss_Generator: 23.5012
# Epoch [18/100] Batch [400/1055] Loss_Critic: -7.2296  Loss_Generator: 28.8584
# Epoch [18/100] Batch [500/1055] Loss_Critic: -7.2230  Loss_Generator: 25.3790
# Epoch [18/100] Batch [600/1055] Loss_Critic: -7.5528  Loss_Generator: 24.5703
# Epoch [18/100] Batch [700/1055] Loss_Critic: -7.5050  Loss_Generator: 25.8177
# Epoch [42/100] Batch [600/1055] Loss_Critic: -5.3084  Loss_Generator: 20.4583
# Epoch [42/100] Batch [700/1055] Loss_Critic: -5.6200  Loss_Generator: 18.2619
# Epoch [42/100] Batch [800/1055] Loss_Critic: -5.1881  Loss_Generator: 19.1898
# Epoch [42/100] Batch [900/1055] Loss_Critic: -5.9267  Loss_Generator: 17.6857
# Epoch [42/100] Batch [1000/1055] Loss_Critic: -4.6560  Loss_Generator: 19.6623
# Epoch [43/100] Batch [0/1055] Loss_Critic: -6.1934  Loss_Generator: 18.6115
# Epoch [43/100] Batch [100/1055] Loss_Critic: -5.5511  Loss_Generator: 19.5216
# Epoch [43/100] Batch [200/1055] Loss_Critic: -5.2998  Loss_Generator: 17.8138
# Epoch [43/100] Batch [300/1055] Loss_Critic: -5.5360  Loss_Generator: 17.7478
# Epoch [43/100] Batch [400/1055] Loss_Critic: -5.4048  Loss_Generator: 18.7017
# Epoch [43/100] Batch [500/1055] Loss_Critic: -5.0658  Loss_Generator: 18.9607
# Epoch [43/100] Batch [600/1055] Loss_Critic: -4.9536  Loss_Generator: 19.2765
# Epoch [43/100] Batch [700/1055] Loss_Critic: -5.5437  Loss_Generator: 19.6316
# Epoch [43/100] Batch [800/1055] Loss_Critic: -5.5098  Loss_Generator: 19.6974
# Epoch [43/100] Batch [900/1055] Loss_Critic: -5.0481  Loss_Generator: 20.4264
# Epoch [43/100] Batch [1000/1055] Loss_Critic: -5.7478  Loss_Generator: 20.1345
# Epoch [44/100] Batch [0/1055] Loss_Critic: -5.5581  Loss_Generator: 20.4558
# Epoch [44/100] Batch [100/1055] Loss_Critic: -5.2195  Loss_Generator: 19.9806
# Epoch [44/100] Batch [200/1055] Loss_Critic: -4.0567  Loss_Generator: 19.5257
# Epoch [44/100] Batch [300/1055] Loss_Critic: -5.8794  Loss_Generator: 18.9504
# Epoch [44/100] Batch [400/1055] Loss_Critic: -5.1994  Loss_Generator: 20.7042
# Epoch [44/100] Batch [500/1055] Loss_Critic: -5.3665  Loss_Generator: 19.0503
# Epoch [44/100] Batch [600/1055] Loss_Critic: -6.1292  Loss_Generator: 18.8852
# Epoch [44/100] Batch [700/1055] Loss_Critic: -5.7029  Loss_Generator: 18.3194
# Epoch [44/100] Batch [800/1055] Loss_Critic: -5.0704  Loss_Generator: 18.8016
# Epoch [44/100] Batch [900/1055] Loss_Critic: -6.0894  Loss_Generator: 18.8432
# Epoch [44/100] Batch [1000/1055] Loss_Critic: -5.3553  Loss_Generator: 18.5783
# Epoch [45/100] Batch [0/1055] Loss_Critic: -5.3831  Loss_Generator: 19.3661
# Epoch [45/100] Batch [100/1055] Loss_Critic: -5.5687  Loss_Generator: 19.1913
# Epoch [45/100] Batch [200/1055] Loss_Critic: -4.5546  Loss_Generator: 18.6086
# Epoch [45/100] Batch [300/1055] Loss_Critic: -5.6686  Loss_Generator: 18.2100
# Epoch [45/100] Batch [400/1055] Loss_Critic: -6.0417  Loss_Generator: 19.3762
# Epoch [45/100] Batch [500/1055] Loss_Critic: -4.9791  Loss_Generator: 20.0669
# Epoch [45/100] Batch [600/1055] Loss_Critic: -5.6013  Loss_Generator: 19.3972
# Epoch [45/100] Batch [700/1055] Loss_Critic: -5.2246  Loss_Generator: 18.7673
# Epoch [45/100] Batch [800/1055] Loss_Critic: -5.7075  Loss_Generator: 19.0890
# Epoch [45/100] Batch [900/1055] Loss_Critic: -4.4448  Loss_Generator: 17.8965
# Epoch [45/100] Batch [1000/1055] Loss_Critic: -5.4391  Loss_Generator: 21.4026
# Epoch [46/100] Batch [0/1055] Loss_Critic: -5.5568  Loss_Generator: 18.9521
# Epoch [46/100] Batch [100/1055] Loss_Critic: -5.6045  Loss_Generator: 16.4804
# Epoch [46/100] Batch [200/1055] Loss_Critic: -5.6598  Loss_Generator: 18.4617
# Epoch [46/100] Batch [300/1055] Loss_Critic: -5.1752  Loss_Generator: 18.4702
# Epoch [46/100] Batch [400/1055] Loss_Critic: -5.1001  Loss_Generator: 18.0891
# Epoch [46/100] Batch [500/1055] Loss_Critic: -6.0365  Loss_Generator: 19.6003
# Epoch [46/100] Batch [600/1055] Loss_Critic: -5.7866  Loss_Generator: 16.9134
# Epoch [46/100] Batch [700/1055] Loss_Critic: -4.6337  Loss_Generator: 20.0473
# Epoch [46/100] Batch [800/1055] Loss_Critic: -4.6987  Loss_Generator: 18.4885
# Epoch [46/100] Batch [900/1055] Loss_Critic: -5.0649  Loss_Generator: 18.8068
# Epoch [46/100] Batch [1000/1055] Loss_Critic: -4.7840  Loss_Generator: 20.9734
# Epoch [47/100] Batch [0/1055] Loss_Critic: -5.4262  Loss_Generator: 17.6354
# Epoch [47/100] Batch [100/1055] Loss_Critic: -5.3020  Loss_Generator: 18.7994
# Epoch [47/100] Batch [200/1055] Loss_Critic: -5.5312  Loss_Generator: 19.8810
# Epoch [47/100] Batch [300/1055] Loss_Critic: -5.1869  Loss_Generator: 20.2721
# Epoch [47/100] Batch [400/1055] Loss_Critic: -5.1255  Loss_Generator: 19.2596
# Epoch [47/100] Batch [500/1055] Loss_Critic: -5.3375  Loss_Generator: 17.8558
# Epoch [47/100] Batch [600/1055] Loss_Critic: -5.4520  Loss_Generator: 17.1586
# Epoch [47/100] Batch [700/1055] Loss_Critic: -5.2562  Loss_Generator: 19.3754
# Epoch [47/100] Batch [800/1055] Loss_Critic: -4.9845  Loss_Generator: 19.5144
# Epoch [47/100] Batch [900/1055] Loss_Critic: -5.2997  Loss_Generator: 18.7496
# Epoch [47/100] Batch [1000/1055] Loss_Critic: -5.3059  Loss_Generator: 17.7036
# Epoch [48/100] Batch [0/1055] Loss_Critic: -5.1831  Loss_Generator: 18.3576
# Epoch [48/100] Batch [100/1055] Loss_Critic: -4.9082  Loss_Generator: 19.5232
# Epoch [48/100] Batch [200/1055] Loss_Critic: -5.0426  Loss_Generator: 18.4783
# Epoch [48/100] Batch [300/1055] Loss_Critic: -5.2874  Loss_Generator: 19.0880
# Epoch [48/100] Batch [400/1055] Loss_Critic: -5.7234  Loss_Generator: 18.5746
# Epoch [48/100] Batch [500/1055] Loss_Critic: -5.8768  Loss_Generator: 18.2169
# Epoch [48/100] Batch [600/1055] Loss_Critic: -5.5624  Loss_Generator: 20.0802
# Epoch [48/100] Batch [700/1055] Loss_Critic: -5.0953  Loss_Generator: 18.7597
# Epoch [48/100] Batch [800/1055] Loss_Critic: -5.0370  Loss_Generator: 18.2507
# Epoch [48/100] Batch [900/1055] Loss_Critic: -5.1284  Loss_Generator: 20.7055
# Epoch [48/100] Batch [1000/1055] Loss_Critic: -4.8644  Loss_Generator: 18.2642
# Epoch [49/100] Batch [0/1055] Loss_Critic: -5.1340  Loss_Generator: 16.3081
# Epoch [49/100] Batch [100/1055] Loss_Critic: -5.0722  Loss_Generator: 19.4247
# Epoch [49/100] Batch [200/1055] Loss_Critic: -5.0577  Loss_Generator: 18.6301
# Epoch [49/100] Batch [300/1055] Loss_Critic: -5.3964  Loss_Generator: 19.8470
# Epoch [49/100] Batch [400/1055] Loss_Critic: -5.3759  Loss_Generator: 17.7795
# Epoch [49/100] Batch [500/1055] Loss_Critic: -5.7143  Loss_Generator: 19.5744
# Epoch [49/100] Batch [600/1055] Loss_Critic: -5.2638  Loss_Generator: 20.8800
# Epoch [49/100] Batch [700/1055] Loss_Critic: -5.8715  Loss_Generator: 18.2999
# Epoch [49/100] Batch [800/1055] Loss_Critic: -5.3021  Loss_Generator: 17.8886
# Epoch [49/100] Batch [900/1055] Loss_Critic: -5.3832  Loss_Generator: 20.3102
# Epoch [49/100] Batch [1000/1055] Loss_Critic: -5.3001  Loss_Generator: 18.8141
# Model checkpoint saved at epoch 50
# Epoch [50/100] Batch [0/1055] Loss_Critic: -5.6342  Loss_Generator: 18.6920
# Epoch [50/100] Batch [100/1055] Loss_Critic: -5.6315  Loss_Generator: 18.3056
# Epoch [50/100] Batch [200/1055] Loss_Critic: -5.5185  Loss_Generator: 18.4536
# Epoch [50/100] Batch [300/1055] Loss_Critic: -5.4790  Loss_Generator: 17.9325
# Epoch [50/100] Batch [400/1055] Loss_Critic: -4.8870  Loss_Generator: 20.0837
# Epoch [50/100] Batch [500/1055] Loss_Critic: -5.2100  Loss_Generator: 18.7278
# Epoch [50/100] Batch [600/1055] Loss_Critic: -4.8302  Loss_Generator: 18.2047
# Epoch [50/100] Batch [700/1055] Loss_Critic: -4.6377  Loss_Generator: 17.3026
# Epoch [50/100] Batch [800/1055] Loss_Critic: -5.1097  Loss_Generator: 19.9010
# Epoch [50/100] Batch [900/1055] Loss_Critic: -5.1869  Loss_Generator: 20.1668
# Epoch [50/100] Batch [1000/1055] Loss_Critic: -4.9201  Loss_Generator: 19.6127
# Epoch [51/100] Batch [0/1055] Loss_Critic: -5.0442  Loss_Generator: 19.7400
# Epoch [51/100] Batch [100/1055] Loss_Critic: -5.5377  Loss_Generator: 17.5403
# Epoch [51/100] Batch [200/1055] Loss_Critic: -5.3874  Loss_Generator: 16.6183
# Epoch [51/100] Batch [300/1055] Loss_Critic: -5.2745  Loss_Generator: 18.4340
# Epoch [51/100] Batch [400/1055] Loss_Critic: -5.7495  Loss_Generator: 17.1808
# Epoch [51/100] Batch [500/1055] Loss_Critic: -4.9573  Loss_Generator: 19.2142
# Epoch [51/100] Batch [600/1055] Loss_Critic: -5.5931  Loss_Generator: 18.3180
# Epoch [51/100] Batch [700/1055] Loss_Critic: -4.9892  Loss_Generator: 17.3672
# Epoch [51/100] Batch [800/1055] Loss_Critic: -5.4231  Loss_Generator: 19.2612
# Epoch [51/100] Batch [900/1055] Loss_Critic: -4.5230  Loss_Generator: 18.5978
# Epoch [51/100] Batch [1000/1055] Loss_Critic: -5.6557  Loss_Generator: 17.1569
# Epoch [52/100] Batch [0/1055] Loss_Critic: -5.1028  Loss_Generator: 17.8849
# Epoch [52/100] Batch [100/1055] Loss_Critic: -4.6817  Loss_Generator: 18.7656
# Epoch [52/100] Batch [200/1055] Loss_Critic: -5.5586  Loss_Generator: 19.2060
# Epoch [52/100] Batch [300/1055] Loss_Critic: -4.5893  Loss_Generator: 18.5251
# Epoch [52/100] Batch [400/1055] Loss_Critic: -5.3518  Loss_Generator: 18.1014
# Epoch [52/100] Batch [500/1055] Loss_Critic: -4.7044  Loss_Generator: 18.4844
# Epoch [52/100] Batch [600/1055] Loss_Critic: -5.3977  Loss_Generator: 19.8045
# Epoch [52/100] Batch [700/1055] Loss_Critic: -5.6133  Loss_Generator: 18.1687
# Epoch [52/100] Batch [800/1055] Loss_Critic: -5.8951  Loss_Generator: 18.6246
# Epoch [52/100] Batch [900/1055] Loss_Critic: -5.9618  Loss_Generator: 20.4044
# Epoch [52/100] Batch [1000/1055] Loss_Critic: -5.1552  Loss_Generator: 19.7812
# Epoch [53/100] Batch [0/1055] Loss_Critic: -5.0346  Loss_Generator: 18.3271
# Epoch [53/100] Batch [100/1055] Loss_Critic: -5.0730  Loss_Generator: 19.5332
# Epoch [53/100] Batch [200/1055] Loss_Critic: -4.8323  Loss_Generator: 19.1747
# Epoch [53/100] Batch [300/1055] Loss_Critic: -5.6256  Loss_Generator: 19.2076
# Epoch [53/100] Batch [400/1055] Loss_Critic: -5.6584  Loss_Generator: 19.6079
# Epoch [53/100] Batch [500/1055] Loss_Critic: -5.4627  Loss_Generator: 20.7529
# Epoch [53/100] Batch [600/1055] Loss_Critic: -5.3310  Loss_Generator: 18.0014
# Epoch [53/100] Batch [700/1055] Loss_Critic: -4.6992  Loss_Generator: 19.1207
# Epoch [53/100] Batch [800/1055] Loss_Critic: -5.5266  Loss_Generator: 19.3676
# Epoch [53/100] Batch [900/1055] Loss_Critic: -5.1321  Loss_Generator: 20.0212
# Epoch [53/100] Batch [1000/1055] Loss_Critic: -4.8306  Loss_Generator: 20.6410
# Epoch [54/100] Batch [0/1055] Loss_Critic: -5.6574  Loss_Generator: 19.8941
# Epoch [54/100] Batch [100/1055] Loss_Critic: -5.9277  Loss_Generator: 17.1795
# Epoch [54/100] Batch [200/1055] Loss_Critic: -5.2648  Loss_Generator: 18.8804
# Epoch [54/100] Batch [300/1055] Loss_Critic: -5.3645  Loss_Generator: 19.4354
# Epoch [54/100] Batch [400/1055] Loss_Critic: -5.0006  Loss_Generator: 17.9226
# Epoch [54/100] Batch [500/1055] Loss_Critic: -4.9561  Loss_Generator: 17.8226
# Epoch [54/100] Batch [600/1055] Loss_Critic: -5.4442  Loss_Generator: 20.8644
# Epoch [54/100] Batch [700/1055] Loss_Critic: -4.3794  Loss_Generator: 19.4256
# Epoch [54/100] Batch [800/1055] Loss_Critic: -4.9671  Loss_Generator: 17.8027
# Epoch [54/100] Batch [900/1055] Loss_Critic: -4.5729  Loss_Generator: 18.8607
# Epoch [54/100] Batch [1000/1055] Loss_Critic: -5.0382  Loss_Generator: 20.2640
# Epoch [55/100] Batch [0/1055] Loss_Critic: -5.4037  Loss_Generator: 19.8352
# Epoch [55/100] Batch [100/1055] Loss_Critic: -4.8600  Loss_Generator: 18.0917
# Epoch [55/100] Batch [200/1055] Loss_Critic: -5.4031  Loss_Generator: 18.7332
# Epoch [55/100] Batch [300/1055] Loss_Critic: -4.8321  Loss_Generator: 18.3468
# Epoch [55/100] Batch [400/1055] Loss_Critic: -4.8239  Loss_Generator: 18.3998
# Epoch [55/100] Batch [500/1055] Loss_Critic: -5.4551  Loss_Generator: 20.0573
# Epoch [55/100] Batch [600/1055] Loss_Critic: -5.1661  Loss_Generator: 19.3296
# Epoch [55/100] Batch [700/1055] Loss_Critic: -5.5658  Loss_Generator: 20.0166
# ...
# Epoch [81/100] Batch [500/1055] Loss_Critic: -5.2717  Loss_Generator: 15.5628
# Epoch [81/100] Batch [600/1055] Loss_Critic: -4.2988  Loss_Generator: 18.3232
# Epoch [81/100] Batch [700/1055] Loss_Critic: -4.5941  Loss_Generator: 17.3537
# Epoch [81/100] Batch [800/1055] Loss_Critic: -4.7135  Loss_Generator: 16.4946
# Epoch [81/100] Batch [900/1055] Loss_Critic: -4.7585  Loss_Generator: 17.0432
# Epoch [81/100] Batch [1000/1055] Loss_Critic: -4.7289  Loss_Generator: 15.0724
# Epoch [82/100] Batch [0/1055] Loss_Critic: -5.0747  Loss_Generator: 17.8818
# Epoch [82/100] Batch [100/1055] Loss_Critic: -4.7114  Loss_Generator: 16.6974
# Epoch [82/100] Batch [200/1055] Loss_Critic: -4.8477  Loss_Generator: 16.2768
# Epoch [82/100] Batch [300/1055] Loss_Critic: -5.0221  Loss_Generator: 15.8292
# Epoch [82/100] Batch [400/1055] Loss_Critic: -4.3075  Loss_Generator: 17.9230
# Epoch [82/100] Batch [500/1055] Loss_Critic: -4.1273  Loss_Generator: 16.0800
# Epoch [82/100] Batch [600/1055] Loss_Critic: -4.7046  Loss_Generator: 17.7839
# Epoch [82/100] Batch [700/1055] Loss_Critic: -4.6835  Loss_Generator: 16.9702
# Epoch [82/100] Batch [800/1055] Loss_Critic: -3.8917  Loss_Generator: 16.3124
# Epoch [82/100] Batch [900/1055] Loss_Critic: -4.3554  Loss_Generator: 16.9423
# Epoch [82/100] Batch [1000/1055] Loss_Critic: -4.8665  Loss_Generator: 16.3900
# Epoch [83/100] Batch [0/1055] Loss_Critic: -4.8217  Loss_Generator: 16.5048
# Epoch [83/100] Batch [100/1055] Loss_Critic: -4.7734  Loss_Generator: 15.6562
# Epoch [83/100] Batch [200/1055] Loss_Critic: -4.5834  Loss_Generator: 18.2183
# Epoch [83/100] Batch [300/1055] Loss_Critic: -5.1748  Loss_Generator: 17.4213
# Epoch [83/100] Batch [400/1055] Loss_Critic: -4.6254  Loss_Generator: 14.9840
# Epoch [83/100] Batch [500/1055] Loss_Critic: -4.6750  Loss_Generator: 17.0529
# Epoch [83/100] Batch [600/1055] Loss_Critic: -5.0418  Loss_Generator: 16.4938
# Epoch [83/100] Batch [700/1055] Loss_Critic: -3.7010  Loss_Generator: 19.2163
# Epoch [83/100] Batch [800/1055] Loss_Critic: -4.5590  Loss_Generator: 16.7127
# Epoch [83/100] Batch [900/1055] Loss_Critic: -4.7707  Loss_Generator: 15.4361
# Epoch [83/100] Batch [1000/1055] Loss_Critic: -4.7339  Loss_Generator: 17.3847
# Epoch [84/100] Batch [0/1055] Loss_Critic: -5.1385  Loss_Generator: 16.5434
# Epoch [84/100] Batch [100/1055] Loss_Critic: -4.1698  Loss_Generator: 17.2012
# Epoch [84/100] Batch [200/1055] Loss_Critic: -4.9345  Loss_Generator: 18.4552
# Epoch [84/100] Batch [300/1055] Loss_Critic: -4.2822  Loss_Generator: 15.8613
# Epoch [84/100] Batch [400/1055] Loss_Critic: -4.9159  Loss_Generator: 16.3298
# Epoch [84/100] Batch [500/1055] Loss_Critic: -4.4696  Loss_Generator: 17.5429
# Epoch [84/100] Batch [600/1055] Loss_Critic: -4.0849  Loss_Generator: 17.0147
# Epoch [84/100] Batch [700/1055] Loss_Critic: -4.6555  Loss_Generator: 16.3857
# Epoch [84/100] Batch [800/1055] Loss_Critic: -4.7142  Loss_Generator: 17.8288
# Epoch [84/100] Batch [900/1055] Loss_Critic: -4.7212  Loss_Generator: 17.3919
# Epoch [84/100] Batch [1000/1055] Loss_Critic: -4.7574  Loss_Generator: 17.1981
# Epoch [85/100] Batch [0/1055] Loss_Critic: -4.2429  Loss_Generator: 17.3628
# Epoch [85/100] Batch [100/1055] Loss_Critic: -4.2021  Loss_Generator: 18.0766
# Epoch [85/100] Batch [200/1055] Loss_Critic: -4.4676  Loss_Generator: 17.1209
# Epoch [85/100] Batch [300/1055] Loss_Critic: -4.6218  Loss_Generator: 17.1439
# Epoch [85/100] Batch [400/1055] Loss_Critic: -4.8074  Loss_Generator: 16.5906
# Epoch [85/100] Batch [500/1055] Loss_Critic: -4.6410  Loss_Generator: 15.7281
# Epoch [85/100] Batch [600/1055] Loss_Critic: -4.2512  Loss_Generator: 16.0438
# Epoch [85/100] Batch [700/1055] Loss_Critic: -4.3428  Loss_Generator: 15.4960
# Epoch [85/100] Batch [800/1055] Loss_Critic: -5.2575  Loss_Generator: 15.5505
# Epoch [85/100] Batch [900/1055] Loss_Critic: -4.9839  Loss_Generator: 17.7631
# Epoch [85/100] Batch [1000/1055] Loss_Critic: -4.7818  Loss_Generator: 14.9800
# Epoch [86/100] Batch [0/1055] Loss_Critic: -3.9535  Loss_Generator: 16.5099
# Epoch [86/100] Batch [100/1055] Loss_Critic: -5.0301  Loss_Generator: 17.6186
# Epoch [89/100] Batch [100/1055] Loss_Critic: -5.0958  Loss_Generator: 16.2509
# Epoch [89/100] Batch [200/1055] Loss_Critic: -4.3458  Loss_Generator: 16.7448
# Epoch [89/100] Batch [300/1055] Loss_Critic: -4.5027  Loss_Generator: 15.8315
# Epoch [89/100] Batch [400/1055] Loss_Critic: -4.3748  Loss_Generator: 15.7093
# Epoch [89/100] Batch [500/1055] Loss_Critic: -4.8940  Loss_Generator: 15.8216
# Epoch [89/100] Batch [600/1055] Loss_Critic: -4.3791  Loss_Generator: 16.7018
# Epoch [89/100] Batch [700/1055] Loss_Critic: -4.5752  Loss_Generator: 16.0006
# Epoch [89/100] Batch [800/1055] Loss_Critic: -4.4752  Loss_Generator: 16.0478
# Epoch [89/100] Batch [900/1055] Loss_Critic: -4.2559  Loss_Generator: 14.7449
# Epoch [89/100] Batch [1000/1055] Loss_Critic: -4.8075  Loss_Generator: 15.5575
# Model checkpoint saved at epoch 90
# Epoch [90/100] Batch [0/1055] Loss_Critic: -4.5876  Loss_Generator: 16.6768
# Epoch [90/100] Batch [100/1055] Loss_Critic: -4.6581  Loss_Generator: 17.3020
# Epoch [90/100] Batch [200/1055] Loss_Critic: -4.8791  Loss_Generator: 17.6430
# Epoch [90/100] Batch [300/1055] Loss_Critic: -4.7118  Loss_Generator: 15.6325
# Epoch [90/100] Batch [400/1055] Loss_Critic: -5.1427  Loss_Generator: 15.4010
# Epoch [90/100] Batch [500/1055] Loss_Critic: -4.2970  Loss_Generator: 15.3948
# Epoch [90/100] Batch [600/1055] Loss_Critic: -4.5459  Loss_Generator: 17.2373
# Epoch [90/100] Batch [700/1055] Loss_Critic: -4.2893  Loss_Generator: 17.3253
# Epoch [90/100] Batch [800/1055] Loss_Critic: -4.2526  Loss_Generator: 17.6125
# Epoch [90/100] Batch [900/1055] Loss_Critic: -5.1401  Loss_Generator: 18.6732
# Epoch [90/100] Batch [1000/1055] Loss_Critic: -4.2375  Loss_Generator: 17.2386
# Epoch [91/100] Batch [0/1055] Loss_Critic: -4.5638  Loss_Generator: 17.0108
# Epoch [91/100] Batch [100/1055] Loss_Critic: -4.2336  Loss_Generator: 18.2872
# Epoch [91/100] Batch [200/1055] Loss_Critic: -4.4114  Loss_Generator: 18.0724
# Epoch [91/100] Batch [300/1055] Loss_Critic: -5.0530  Loss_Generator: 17.1350
# Epoch [91/100] Batch [400/1055] Loss_Critic: -4.0512  Loss_Generator: 16.9207
# Epoch [91/100] Batch [500/1055] Loss_Critic: -5.1741  Loss_Generator: 17.2498
# Epoch [91/100] Batch [600/1055] Loss_Critic: -4.3813  Loss_Generator: 16.2747
# Epoch [91/100] Batch [700/1055] Loss_Critic: -4.3078  Loss_Generator: 17.4422
# Epoch [91/100] Batch [800/1055] Loss_Critic: -4.5786  Loss_Generator: 16.9506
# Epoch [91/100] Batch [900/1055] Loss_Critic: -4.6467  Loss_Generator: 18.4563
# Epoch [91/100] Batch [1000/1055] Loss_Critic: -4.4417  Loss_Generator: 18.3540
# Epoch [92/100] Batch [0/1055] Loss_Critic: -4.7739  Loss_Generator: 18.8287
# Epoch [92/100] Batch [100/1055] Loss_Critic: -4.1040  Loss_Generator: 16.9836
# Epoch [92/100] Batch [200/1055] Loss_Critic: -4.3211  Loss_Generator: 16.1487
# Epoch [92/100] Batch [300/1055] Loss_Critic: -4.4987  Loss_Generator: 16.7450
# Epoch [92/100] Batch [400/1055] Loss_Critic: -4.2701  Loss_Generator: 17.0307
# Epoch [92/100] Batch [500/1055] Loss_Critic: -4.8279  Loss_Generator: 16.2076
# Epoch [92/100] Batch [600/1055] Loss_Critic: -4.1416  Loss_Generator: 17.7684
# Epoch [92/100] Batch [700/1055] Loss_Critic: -4.6078  Loss_Generator: 15.9024
# Epoch [92/100] Batch [800/1055] Loss_Critic: -4.5412  Loss_Generator: 16.3916
# Epoch [92/100] Batch [900/1055] Loss_Critic: -4.4374  Loss_Generator: 15.7181
# Epoch [92/100] Batch [1000/1055] Loss_Critic: -4.4291  Loss_Generator: 15.8031
# Epoch [93/100] Batch [0/1055] Loss_Critic: -4.5688  Loss_Generator: 15.6312
# Epoch [93/100] Batch [100/1055] Loss_Critic: -5.0237  Loss_Generator: 14.4784
# Epoch [93/100] Batch [200/1055] Loss_Critic: -4.7932  Loss_Generator: 17.7502
# Epoch [93/100] Batch [300/1055] Loss_Critic: -4.4496  Loss_Generator: 16.6200
# Epoch [93/100] Batch [400/1055] Loss_Critic: -4.5838  Loss_Generator: 16.2052
# Epoch [93/100] Batch [500/1055] Loss_Critic: -3.9888  Loss_Generator: 17.4602
# Epoch [93/100] Batch [600/1055] Loss_Critic: -4.3703  Loss_Generator: 16.9932
# Epoch [93/100] Batch [700/1055] Loss_Critic: -5.0202  Loss_Generator: 16.2178
# Epoch [93/100] Batch [800/1055] Loss_Critic: -4.7068  Loss_Generator: 15.2906
# Epoch [93/100] Batch [900/1055] Loss_Critic: -4.4492  Loss_Generator: 17.1087
# Epoch [93/100] Batch [1000/1055] Loss_Critic: -4.4521  Loss_Generator: 16.4106
# Epoch [94/100] Batch [0/1055] Loss_Critic: -5.4137  Loss_Generator: 17.3404
# Epoch [94/100] Batch [100/1055] Loss_Critic: -4.6402  Loss_Generator: 16.7817
# Epoch [94/100] Batch [200/1055] Loss_Critic: -4.6535  Loss_Generator: 16.1505
# Epoch [94/100] Batch [300/1055] Loss_Critic: -4.7758  Loss_Generator: 15.6152
# Epoch [94/100] Batch [400/1055] Loss_Critic: -4.3337  Loss_Generator: 18.2588
# Epoch [94/100] Batch [500/1055] Loss_Critic: -4.3029  Loss_Generator: 16.5620
# Epoch [94/100] Batch [600/1055] Loss_Critic: -4.7263  Loss_Generator: 16.4524
# Epoch [94/100] Batch [700/1055] Loss_Critic: -3.7645  Loss_Generator: 16.7663
# Epoch [94/100] Batch [800/1055] Loss_Critic: -4.2590  Loss_Generator: 15.9369
# Epoch [94/100] Batch [900/1055] Loss_Critic: -4.5111  Loss_Generator: 16.4442
# Epoch [94/100] Batch [1000/1055] Loss_Critic: -3.9374  Loss_Generator: 16.3795
# Epoch [95/100] Batch [0/1055] Loss_Critic: -5.2882  Loss_Generator: 16.7436
# Epoch [95/100] Batch [100/1055] Loss_Critic: -4.6272  Loss_Generator: 15.1144
# Epoch [95/100] Batch [200/1055] Loss_Critic: -4.3597  Loss_Generator: 16.8533
# Epoch [95/100] Batch [300/1055] Loss_Critic: -4.8740  Loss_Generator: 14.8083
# Epoch [95/100] Batch [400/1055] Loss_Critic: -4.4302  Loss_Generator: 16.1850
# Epoch [95/100] Batch [500/1055] Loss_Critic: -3.9085  Loss_Generator: 14.9790
# Epoch [95/100] Batch [600/1055] Loss_Critic: -4.8401  Loss_Generator: 17.1600
# Epoch [95/100] Batch [700/1055] Loss_Critic: -4.3069  Loss_Generator: 17.8940
# Epoch [95/100] Batch [800/1055] Loss_Critic: -4.4991  Loss_Generator: 15.9808
# Epoch [95/100] Batch [900/1055] Loss_Critic: -4.8948  Loss_Generator: 15.8005
# Epoch [95/100] Batch [1000/1055] Loss_Critic: -4.7777  Loss_Generator: 16.7914
# Epoch [96/100] Batch [0/1055] Loss_Critic: -4.1514  Loss_Generator: 16.0713
# Epoch [96/100] Batch [100/1055] Loss_Critic: -4.4092  Loss_Generator: 16.1371
# Epoch [96/100] Batch [200/1055] Loss_Critic: -4.2201  Loss_Generator: 16.1083
# Epoch [96/100] Batch [300/1055] Loss_Critic: -4.6977  Loss_Generator: 14.5389
# Epoch [96/100] Batch [400/1055] Loss_Critic: -4.8453  Loss_Generator: 15.8392
# Epoch [96/100] Batch [500/1055] Loss_Critic: -4.7088  Loss_Generator: 14.2507
# Epoch [96/100] Batch [600/1055] Loss_Critic: -4.8868  Loss_Generator: 15.1270
# Epoch [96/100] Batch [700/1055] Loss_Critic: -4.7355  Loss_Generator: 16.0824
# Epoch [96/100] Batch [800/1055] Loss_Critic: -4.8296  Loss_Generator: 15.8761
# Epoch [96/100] Batch [900/1055] Loss_Critic: -4.2574  Loss_Generator: 17.6346
# Epoch [96/100] Batch [1000/1055] Loss_Critic: -5.4403  Loss_Generator: 15.4116
# Epoch [97/100] Batch [0/1055] Loss_Critic: -4.4339  Loss_Generator: 16.0672
# Epoch [97/100] Batch [100/1055] Loss_Critic: -4.2859  Loss_Generator: 16.7738
# Epoch [97/100] Batch [200/1055] Loss_Critic: -3.8093  Loss_Generator: 16.1396
# Epoch [97/100] Batch [300/1055] Loss_Critic: -4.8287  Loss_Generator: 15.1299
# Epoch [97/100] Batch [400/1055] Loss_Critic: -5.4610  Loss_Generator: 15.5687
# Epoch [97/100] Batch [500/1055] Loss_Critic: -4.3836  Loss_Generator: 14.2569
# Epoch [97/100] Batch [600/1055] Loss_Critic: -4.0415  Loss_Generator: 16.6316
# Epoch [97/100] Batch [700/1055] Loss_Critic: -4.3281  Loss_Generator: 15.2179
# Epoch [97/100] Batch [800/1055] Loss_Critic: -4.5058  Loss_Generator: 15.9677
# Epoch [97/100] Batch [900/1055] Loss_Critic: -4.1998  Loss_Generator: 16.4668
# Epoch [97/100] Batch [1000/1055] Loss_Critic: -4.1710  Loss_Generator: 17.4355
# Epoch [98/100] Batch [0/1055] Loss_Critic: -4.8022  Loss_Generator: 16.2820
# Epoch [98/100] Batch [100/1055] Loss_Critic: -5.1095  Loss_Generator: 15.4949
# Epoch [98/100] Batch [200/1055] Loss_Critic: -4.0135  Loss_Generator: 17.5706
# Epoch [98/100] Batch [300/1055] Loss_Critic: -4.1462  Loss_Generator: 14.6553
# Epoch [98/100] Batch [400/1055] Loss_Critic: -4.5999  Loss_Generator: 18.2029
# Epoch [98/100] Batch [500/1055] Loss_Critic: -4.4177  Loss_Generator: 17.5594
# Epoch [98/100] Batch [600/1055] Loss_Critic: -4.4354  Loss_Generator: 16.7387
# Epoch [98/100] Batch [700/1055] Loss_Critic: -4.4495  Loss_Generator: 15.8545
# Epoch [98/100] Batch [800/1055] Loss_Critic: -4.4318  Loss_Generator: 16.8670
# Epoch [98/100] Batch [900/1055] Loss_Critic: -4.7487  Loss_Generator: 14.4346
# Epoch [98/100] Batch [1000/1055] Loss_Critic: -4.1150  Loss_Generator: 15.7088
# Epoch [99/100] Batch [0/1055] Loss_Critic: -3.9240  Loss_Generator: 16.9374
# Epoch [99/100] Batch [100/1055] Loss_Critic: -5.0298  Loss_Generator: 16.3388
# Epoch [99/100] Batch [200/1055] Loss_Critic: -3.9923  Loss_Generator: 17.0975
# Epoch [99/100] Batch [300/1055] Loss_Critic: -4.3440  Loss_Generator: 17.1786
# Epoch [99/100] Batch [400/1055] Loss_Critic: -3.8766  Loss_Generator: 15.0186
# Epoch [99/100] Batch [500/1055] Loss_Critic: -5.1079  Loss_Generator: 16.5034
# Epoch [99/100] Batch [600/1055] Loss_Critic: -4.8449  Loss_Generator: 16.7772
# Epoch [99/100] Batch [700/1055] Loss_Critic: -4.6179  Loss_Generator: 16.4259
# Epoch [99/100] Batch [800/1055] Loss_Critic: -4.8080  Loss_Generator: 15.8808
# Epoch [99/100] Batch [900/1055] Loss_Critic: -4.7704  Loss_Generator: 16.5524
# Epoch [99/100] Batch [1000/1055] Loss_Critic: -4.4926  Loss_Generator: 16.6405
# Model checkpoint saved at epoch 100

# %%
torch.save({
    'generator_state_dict': generator.state_dict(),
    'critic_state_dict': critic.state_dict(),
    'optimizerG_state_dict': optimizerG.state_dict(),
    'optimizerC_state_dict': optimizerC.state_dict(),
    'epoch': num_epochs,
}, f'models/{formatted_dataset_name}/model_checkpoint_latest.pth')
print(f'Latest model checkpoint saved')

# Save final loss data
loss_data = {
    "G_losses": G_losses,
    "C_losses": C_losses
}

with open(f"models/{formatted_dataset_name}/losses_final.json", "w") as f:
    json.dump(loss_data, f)

print("Final loss data saved in models/losses_final.json")
# Out:
# Latest model checkpoint saved
# Final loss data saved in models/losses_final.json

# %%
# Create an array for critic iterations (recorded every iteration)
iterations_critic = np.arange(len(C_losses))

# Extract the indices and corresponding losses for generator updates (non-None values)
gen_indices = [i for i, loss in enumerate(G_losses) if loss is not None]
gen_losses = [loss for loss in G_losses if loss is not None]

plt.figure(figsize=(10,5))
plt.title("Generator and Critic Loss During Training")
plt.plot(iterations_critic, C_losses, label="Critic Loss")
plt.plot(gen_indices, gen_losses, label="Generator Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()
